# %%
# !pip install fairseq

# %%
import sys
import os

py_file_location = "/content/drive/My Drive/Replace_encoder"
sys.path.append(os.path.abspath(py_file_location))

# %%
from replace_utils import *

# %%
model_a_path = "/content/drive/MyDrive/ModelTraining/pairseq_training/models/ja_en/v3_based_on_subtitle/checkpoint_10_800.pt"
model_b_path = "/content/drive/MyDrive/ModelTraining/pairseq_training/models/ja_en/v3_based_on_subtitle/checkpoint_9_700.pt"
save_dir = "/content/drive/MyDrive/Replace_encoder/Example"

# %%
replace_and_save(model_a_path, model_b_path, save_dir)
